# %%
class circle():
    
    def __init__(self,r):
        self.radius = r
    def get_area(self):
        
        print(round(self.radius*self.radius*3.14))
    def get_perimeter(self):
        print(round(2*self.radius*3.14))

c = circle(4.44)
c.get_area()
c.get_perimeter()
# Out:
# 62
# 28
