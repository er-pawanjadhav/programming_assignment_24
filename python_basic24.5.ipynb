# %%
def is_triplet(a):
    a = sorted(a)
    f = a[0]**2
    s = a[1]**2
    c = f+s
    l = a[2]**2
    if c==l:
        return True
    else:
        return False
    
b =[13,5,12]   
print(is_triplet(b))
# Out:
# True
