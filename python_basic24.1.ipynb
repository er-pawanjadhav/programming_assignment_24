# %%
a = 10
l = []
for i in range(1,a+1):
    if i%4==0:
        i=i*10
    l.append(i)
print(l)
# Out:
# [1, 2, 3, 40, 5, 6, 7, 80, 9, 10]

# %%
a = 10
l = []
ans = [ l.append(i*10)  if i%4==0 else  l.append(i)  for i in range(1,a+1) ]
print(l)
# Out:
# [1, 2, 3, 40, 5, 6, 7, 80, 9, 10]
